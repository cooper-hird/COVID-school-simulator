# %% [markdown]
# <a href="https://colab.research.google.com/github/cooper-hird/COVID-school-simulator/blob/main/All_Game_Scores_Page.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
from collections import namedtuple


######################################################################################################
            ### NCAA.com Box Scores Request ###
######################################################################################################
# Define the URL for the GET request
url = 'https://www.ncaa.com/scoreboard/basketball-men/d1/2024/12/04/all-conf'

# Send the GET request
response = requests.get(url)

games = []

############### Check for a response ###############
if 'text/html' in response.headers.get('content-type', ''):
    soup = BeautifulSoup(response.content, 'html.parser')
    #####Get Page Title#####
    #title = soup.title.string
    #print(f"Page title: {title}")

    ############### Pull All Team Names, Scores, and Determine Winner #################
    game_records = {}
    game_pods = soup.find_all('div', class_='gamePod')
    for game in game_pods:
        # Find team info (team name/score/rank)
        teams = game.find_all('span', class_='gamePod-game-team-name')
        scores = game.find_all('span', class_='gamePod-game-team-score')
        ranks = game.find_all('span', class_='gamePod-game-team-rank')

        # Ensure that there are two teams and two scores per game (home and away)
        if len(teams) == 2 and len(scores) == 2:
            # Adjust the order to print Home Team first and Away Team second
            home_team = teams[1].text.strip()  # Home team is the second in the list
            away_team = teams[0].text.strip()  # Away team is the first in the list

            home_rank = ranks[1].text.strip() or 'NR'  # Home team rank is the second rank
            away_rank = ranks[0].text.strip() or 'NR'  # Away team rank is the first rank

            home_score = int(scores[1].text.strip())  # Home team score is the second score
            away_score = int(scores[0].text.strip())  # Away team score is the first score

        # Identify winner
        winner = None
        if home_score > away_score:
            winner = home_team
        elif away_score > home_score:
            winner = away_team
        else:
            winner = "I guess this sport has ties?"

        # Print list
        #print(f"Home Team: #{home_rank} {home_team}, Away Team: #{away_rank} {away_team}, Scores: {home_score}-{away_score}, \n Winner: {winner}")
        defaultrank = 400
        default_wawscore = 0
        game = {
            'home_team_list': home_team,
            'away_team_list': away_team,
            'home_score_list': home_score,
            'away_score_list': away_score,
            'home_rank_list': defaultrank,
            'away_rank_list': defaultrank,
            'winner_list': winner,
            'composite_score': default_wawscore
              }
        games.append(game)

#    for x in range(len(home_teams)):
#        print(f"Home Team: {home_teams[x]}, Away Team: {away_teams[x]}, Scores: {home_scores[x]}-{away_scores[x]}, \n Winner: {winners[x]}")
else:
    print("The response is not in HTML format or failed to fetch. Currently, this script only works with HTML input.")



######################################################################################################
            ### NCAAM NET Rankings Request ###
######################################################################################################
url = 'https://www.ncaa.com/rankings/basketball-men/d1/ncaa-mens-basketball-net-rankings'

response = requests.get(url)
teams_rankings_dict = {}
############### Check for a response ###############
if 'text/html' in response.headers.get('content-type', ''):
    soup = BeautifulSoup(response.content, 'html.parser')
    #####Get Page Title#####
    #title = soup.title.string
    #print(f"Page title: {title}")

    rows = soup.find_all('div', class_='layout-content')
    tr_data = []
    td_data = []
    for row in rows:
      trs = row.find_all('tr')
      for tr in trs:
        tds = tr.find_all('td')
        for td in tds:
          td_data.append(td.text.strip())

    # Group the data into chunks of 12
    grouped_data = [td_data[i:i+12] for i in range(0, len(td_data), 12)]


    for i, group in enumerate(grouped_data):
        teams_rankings_dict[group[2]] = group[0]

else:
    print("The response is not in HTML format or failed to fetch. Currently, this script only works with HTML input.")


######################################################################################################
            ### Calculating WAW Score (composite game score) ###
######################################################################################################
for game in games:
    # Update the rank of the home team from the teams_rankings_dict
    game['home_rank_list'] = int(teams_rankings_dict.get(game['home_team_list'], 400))

    # Update the rank of the away team from the teams_rankings_dict
    game['away_rank_list'] = int(teams_rankings_dict.get(game['away_team_list'], 400))

    final_score_factor = 2
    ranking_factor = 1
    upset_factor = .5

    final_score_weight = 0.7
    ranking_score_weight = 0.2
    upset_score_weight = 0.1

    closeness_score = max(0, 100 - (abs(game['home_score_list'] - game['away_score_list']) * final_score_factor))
    rankings_score = max(0, min(100, 100 - (((game['home_rank_list']+game['away_rank_list'])/2) * ranking_factor)))
    upset_score = 0
    # Calculate upset score (if the winning team has a lower rank than the losing team)
    if game['winner_list'] == game['home_team_list']:
        if game['home_rank_list'] > game['away_rank_list']:  # Home team is ranked worse (higher number)
         #   upset_score = min(100, (game['away_rank_list'] - game['home_rank_list']) * upset_factor)  # Scaled difference
            upset_score = max(0, min(100, ((game['home_rank_list'] - game['away_rank_list']) * upset_factor) * (1 - (game['away_rank_list'] / 400))))  # Normalize upset based on rank

        else:
            upset_score = 0  # No upset if home team has a better rank
    elif game['winner_list'] == game['away_team_list']:
        if game['away_rank_list'] > game['home_rank_list']:  # Away team is ranked worse (higher number)
        #    upset_score = min(100, (game['home_rank_list'] - game['away_rank_list']) * upset_factor)  # Scaled difference
            upset_score = max(0, min(100, ((game['away_rank_list'] - game['home_rank_list']) * upset_factor) * (1 - (game['home_rank_list'] / 400))))  # Normalize upset based on rank
        else:
            upset_score = 0  # No upset if away team has a better rank
    else:
        upset_score = 0  # No upset in the case of a tie (though ties are unlikely in basketball)


    game['composite_score'] = round((closeness_score * final_score_weight) + (rankings_score * ranking_score_weight) + (upset_score * upset_score_weight),1)


# Sort the games in descending order based on the WAW score
sorted_games = sorted(games, key=lambda g: g['composite_score'], reverse=True)

# Print the sorted games with their WAW scores
for game in sorted_games:
    ########## CSV list ##########
    print(f"{game['home_team_list']}, {game['away_team_list']}, {game['home_score_list']}, {game['away_score_list']}, {game['home_rank_list']}, {game['away_rank_list']}, {game['winner_list']}, {game['composite_score']}, |")
    print("\n")


    ########### Fancy looking output ##########
    print(f"Home Team: {game['home_team_list']} (Rank: {game['home_rank_list']}) vs Away Team: {game['away_team_list']} (Rank: {game['away_rank_list']})")
    print(f"Scores: {game['home_score_list']} - {game['away_score_list']}")
    print(f"Winner: {game['winner_list']}")
    if game['winner_list'] == game['home_team_list'] and game['home_rank_list'] > game['away_rank_list']:
        print(f"Upset Alert")
    print(f"WAW Score: {game['composite_score']}")
    print()  # Newline for readability
# Out:
# Duke, Auburn, 84, 78, 3, 1, Duke, 81.3, |
#
#
# Home Team: Duke (Rank: 3) vs Away Team: Auburn (Rank: 1)
# Scores: 84 - 78
# Winner: Duke
# Upset Alert
# WAW Score: 81.3
#
# UConn, Baylor, 76, 72, 14, 18, UConn, 81.2, |
#
#
# Home Team: UConn (Rank: 14) vs Away Team: Baylor (Rank: 18)
# Scores: 76 - 72
# Winner: UConn
# WAW Score: 81.2
#
# Iowa St., Marquette, 81, 70, 5, 10, Iowa St., 73.1, |
#
#
# Home Team: Iowa St. (Rank: 5) vs Away Team: Marquette (Rank: 10)
# Scores: 81 - 70
# Winner: Iowa St.
# WAW Score: 73.1
#
# NC State, Texas, 59, 63, 108, 47, Texas, 68.9, |
#
#
# Home Team: NC State (Rank: 108) vs Away Team: Texas (Rank: 47)
# Scores: 59 - 63
# Winner: Texas
# WAW Score: 68.9
#
# Holy Cross, Harvard, 68, 67, 247, 280, Holy Cross, 68.6, |
#
#
# Home Team: Holy Cross (Rank: 247) vs Away Team: Harvard (Rank: 280)
# Scores: 68 - 67
# Winner: Holy Cross
# WAW Score: 68.6
#
# Campbell, Coastal Carolina, 57, 58, 314, 258, Coastal Carolina, 68.6, |
#
#
# Home Team: Campbell (Rank: 314) vs Away Team: Coastal Carolina (Rank: 258)
# Scores: 57 - 58
# Winner: Coastal Carolina
# WAW Score: 68.6
#
# Southern California, Oregon, 60, 68, 96, 16, Oregon, 67.6, |
#
#
# Home Team: Southern California (Rank: 96) vs Away Team: Oregon (Rank: 16)
# Scores: 60 - 68
# Winner: Oregon
# WAW Score: 67.6
#
# Montana, South Dakota St., 71, 67, 194, 110, Montana, 67.4, |
#
#
# Home Team: Montana (Rank: 194) vs Away Team: South Dakota St. (Rank: 110)
# Scores: 71 - 67
# Winner: Montana
# Upset Alert
# WAW Score: 67.4
#
# Belmont, Illinois St., 99, 97, 119, 138, Belmont, 67.2, |
#
#
# Home Team: Belmont (Rank: 119) vs Away Team: Illinois St. (Rank: 138)
# Scores: 99 - 97
# Winner: Belmont
# WAW Score: 67.2
#
# FGCU, Furman, 73, 76, 161, 83, Furman, 65.8, |
#
#
# Home Team: FGCU (Rank: 161) vs Away Team: Furman (Rank: 83)
# Scores: 73 - 76
# Winner: Furman
# WAW Score: 65.8
#
# Marshall, Morehead St., 80, 77, 199, 323, Marshall, 65.8, |
#
#
# Home Team: Marshall (Rank: 199) vs Away Team: Morehead St. (Rank: 323)
# Scores: 80 - 77
# Winner: Marshall
# WAW Score: 65.8
#
# Fairfield, Rider, 78, 75, 301, 312, Fairfield, 65.8, |
#
#
# Home Team: Fairfield (Rank: 301) vs Away Team: Rider (Rank: 312)
# Scores: 78 - 75
# Winner: Fairfield
# WAW Score: 65.8
#
# Utah St., Wyoming, 70, 67, 43, 205, Utah St., 65.8, |
#
#
# Home Team: Utah St. (Rank: 43) vs Away Team: Wyoming (Rank: 205)
# Scores: 70 - 67
# Winner: Utah St.
# WAW Score: 65.8
#
# Creighton, Kansas, 76, 63, 80, 17, Creighton, 65.1, |
#
#
# Home Team: Creighton (Rank: 80) vs Away Team: Kansas (Rank: 17)
# Scores: 76 - 63
# Winner: Creighton
# Upset Alert
# WAW Score: 65.1
#
# Massachusetts, Central Conn. St., 69, 73, 239, 132, Central Conn. St., 64.4, |
#
#
# Home Team: Massachusetts (Rank: 239) vs Away Team: Central Conn. St. (Rank: 132)
# Scores: 69 - 73
# Winner: Central Conn. St.
# WAW Score: 64.4
#
# Weber St., North Dakota St., 73, 77, 212, 93, North Dakota St., 64.4, |
#
#
# Home Team: Weber St. (Rank: 212) vs Away Team: North Dakota St. (Rank: 93)
# Scores: 73 - 77
# Winner: North Dakota St.
# WAW Score: 64.4
#
# Memphis, Louisiana Tech, 81, 71, 33, 84, Memphis, 64.3, |
#
#
# Home Team: Memphis (Rank: 33) vs Away Team: Louisiana Tech (Rank: 84)
# Scores: 81 - 71
# Winner: Memphis
# WAW Score: 64.3
#
# North Carolina, Alabama, 79, 94, 45, 13, Alabama, 63.2, |
#
#
# Home Team: North Carolina (Rank: 45) vs Away Team: Alabama (Rank: 13)
# Scores: 79 - 94
# Winner: Alabama
# WAW Score: 63.2
#
# Kansas City, Idaho, 77, 82, 268, 279, Idaho, 63.2, |
#
#
# Home Team: Kansas City (Rank: 268) vs Away Team: Idaho (Rank: 279)
# Scores: 77 - 82
# Winner: Idaho
# WAW Score: 63.2
#
# Little Rock, Central Ark., 63, 57, 257, 348, Little Rock, 61.6, |
#
#
# Home Team: Little Rock (Rank: 257) vs Away Team: Central Ark. (Rank: 348)
# Scores: 63 - 57
# Winner: Little Rock
# WAW Score: 61.6
#
# New Mexico, San Jose St., 83, 77, 81, 218, New Mexico, 61.6, |
#
#
# Home Team: New Mexico (Rank: 81) vs Away Team: San Jose St. (Rank: 218)
# Scores: 83 - 77
# Winner: New Mexico
# WAW Score: 61.6
#
# Eastern Wash., North Dakota, 87, 81, 238, 289, Eastern Wash., 61.6, |
#
#
# Home Team: Eastern Wash. (Rank: 238) vs Away Team: North Dakota (Rank: 289)
# Scores: 87 - 81
# Winner: Eastern Wash.
# WAW Score: 61.6
#
# Oral Roberts, Northern Ariz., 83, 76, 338, 276, Oral Roberts, 61.2, |
#
#
# Home Team: Oral Roberts (Rank: 338) vs Away Team: Northern Ariz. (Rank: 276)
# Scores: 83 - 76
# Winner: Oral Roberts
# Upset Alert
# WAW Score: 61.2
#
# American, George Washington, 81, 71, 251, 135, American, 59.8, |
#
#
# Home Team: American (Rank: 251) vs Away Team: George Washington (Rank: 135)
# Scores: 81 - 71
# Winner: American
# Upset Alert
# WAW Score: 59.8
#
# Texas Tech, DePaul, 76, 62, 29, 82, Texas Tech, 59.3, |
#
#
# Home Team: Texas Tech (Rank: 29) vs Away Team: DePaul (Rank: 82)
# Scores: 76 - 62
# Winner: Texas Tech
# WAW Score: 59.3
#
# New Mexico St., Abilene Christian, 70, 78, 235, 207, Abilene Christian, 58.8, |
#
#
# Home Team: New Mexico St. (Rank: 235) vs Away Team: Abilene Christian (Rank: 207)
# Scores: 70 - 78
# Winner: Abilene Christian
# WAW Score: 58.8
#
# IU Indy, Green Bay, 84, 75, 326, 327, IU Indy, 57.4, |
#
#
# Home Team: IU Indy (Rank: 326) vs Away Team: Green Bay (Rank: 327)
# Scores: 84 - 75
# Winner: IU Indy
# WAW Score: 57.4
#
# Fordham, FDU, 84, 75, 188, 316, Fordham, 57.4, |
#
#
# Home Team: Fordham (Rank: 188) vs Away Team: FDU (Rank: 316)
# Scores: 84 - 75
# Winner: Fordham
# WAW Score: 57.4
#
# FIU, Fla. Atlantic, 77, 88, 248, 87, Fla. Atlantic, 54.6, |
#
#
# Home Team: FIU (Rank: 248) vs Away Team: Fla. Atlantic (Rank: 87)
# Scores: 77 - 88
# Winner: Fla. Atlantic
# WAW Score: 54.6
#
# Omaha, Montana St., 65, 76, 295, 139, Montana St., 54.6, |
#
#
# Home Team: Omaha (Rank: 295) vs Away Team: Montana St. (Rank: 139)
# Scores: 65 - 76
# Winner: Montana St.
# WAW Score: 54.6
#
# Seton Hall, NJIT, 67, 56, 184, 352, Seton Hall, 54.6, |
#
#
# Home Team: Seton Hall (Rank: 184) vs Away Team: NJIT (Rank: 352)
# Scores: 67 - 56
# Winner: Seton Hall
# WAW Score: 54.6
#
# Florida, Virginia, 87, 69, 6, 100, Florida, 54.2, |
#
#
# Home Team: Florida (Rank: 6) vs Away Team: Virginia (Rank: 100)
# Scores: 87 - 69
# Winner: Florida
# WAW Score: 54.2
#
# Western Caro., Bellarmine, 86, 74, 347, 349, Western Caro., 53.2, |
#
#
# Home Team: Western Caro. (Rank: 347) vs Away Team: Bellarmine (Rank: 349)
# Scores: 86 - 74
# Winner: Western Caro.
# WAW Score: 53.2
#
# Northern Colo., St. Thomas (MN), 75, 87, 148, 121, St. Thomas (MN), 53.2, |
#
#
# Home Team: Northern Colo. (Rank: 148) vs Away Team: St. Thomas (MN) (Rank: 121)
# Scores: 75 - 87
# Winner: St. Thomas (MN)
# WAW Score: 53.2
#
# UAlbany, Columbia, 88, 73, 206, 97, UAlbany, 53.1, |
#
#
# Home Team: UAlbany (Rank: 206) vs Away Team: Columbia (Rank: 97)
# Scores: 88 - 73
# Winner: UAlbany
# Upset Alert
# WAW Score: 53.1
#
# Maryland, Ohio St., 83, 59, 8, 37, Maryland, 51.9, |
#
#
# Home Team: Maryland (Rank: 8) vs Away Team: Ohio St. (Rank: 37)
# Scores: 83 - 59
# Winner: Maryland
# WAW Score: 51.9
#
# Wagner, Coppin St., 65, 52, 322, 362, Wagner, 51.8, |
#
#
# Home Team: Wagner (Rank: 322) vs Away Team: Coppin St. (Rank: 362)
# Scores: 65 - 52
# Winner: Wagner
# WAW Score: 51.8
#
# Mercer, West Ga., 86, 72, 244, 341, Mercer, 50.4, |
#
#
# Home Team: Mercer (Rank: 244) vs Away Team: West Ga. (Rank: 341)
# Scores: 86 - 72
# Winner: Mercer
# WAW Score: 50.4
#
# Robert Morris, Youngstown St., 58, 72, 237, 201, Youngstown St., 50.4, |
#
#
# Home Team: Robert Morris (Rank: 237) vs Away Team: Youngstown St. (Rank: 201)
# Scores: 58 - 72
# Winner: Youngstown St.
# WAW Score: 50.4
#
# South Dakota, Idaho St., 94, 80, 180, 191, South Dakota, 50.4, |
#
#
# Home Team: South Dakota (Rank: 180) vs Away Team: Idaho St. (Rank: 191)
# Scores: 94 - 80
# Winner: South Dakota
# WAW Score: 50.4
#
# Virginia Tech, Vanderbilt, 64, 80, 190, 40, Vanderbilt, 47.6, |
#
#
# Home Team: Virginia Tech (Rank: 190) vs Away Team: Vanderbilt (Rank: 40)
# Scores: 64 - 80
# Winner: Vanderbilt
# WAW Score: 47.6
#
# Bucknell, St. Bonaventure, 47, 64, 246, 53, St. Bonaventure, 46.2, |
#
#
# Home Team: Bucknell (Rank: 246) vs Away Team: St. Bonaventure (Rank: 53)
# Scores: 47 - 64
# Winner: St. Bonaventure
# WAW Score: 46.2
#
# Seattle U, Portland St., 91, 74, 145, 259, Seattle U, 46.2, |
#
#
# Home Team: Seattle U (Rank: 145) vs Away Team: Portland St. (Rank: 259)
# Scores: 91 - 74
# Winner: Seattle U
# WAW Score: 46.2
#
# Minnesota, Michigan St., 72, 90, 173, 20, Michigan St., 45.5, |
#
#
# Home Team: Minnesota (Rank: 173) vs Away Team: Michigan St. (Rank: 20)
# Scores: 72 - 90
# Winner: Michigan St.
# WAW Score: 45.5
#
# Mississippi St., Pittsburgh, 90, 57, 19, 11, Mississippi St., 41.2, |
#
#
# Home Team: Mississippi St. (Rank: 19) vs Away Team: Pittsburgh (Rank: 11)
# Scores: 90 - 57
# Winner: Mississippi St.
# Upset Alert
# WAW Score: 41.2
#
# Tulsa, Oklahoma St., 55, 76, 321, 102, Oklahoma St., 40.6, |
#
#
# Home Team: Tulsa (Rank: 321) vs Away Team: Oklahoma St. (Rank: 102)
# Scores: 55 - 76
# Winner: Oklahoma St.
# WAW Score: 40.6
#
# Denver, Sacramento St., 80, 59, 302, 339, Denver, 40.6, |
#
#
# Home Team: Denver (Rank: 302) vs Away Team: Sacramento St. (Rank: 339)
# Scores: 80 - 59
# Winner: Denver
# WAW Score: 40.6
#
# Charlotte, Livingstone, 83, 61, 253, 400, Charlotte, 39.2, |
#
#
# Home Team: Charlotte (Rank: 253) vs Away Team: Livingstone (Rank: 400)
# Scores: 83 - 61
# Winner: Charlotte
# WAW Score: 39.2
#
# Fresno St., San Diego St., 62, 84, 270, 56, San Diego St., 39.2, |
#
#
# Home Team: Fresno St. (Rank: 270) vs Away Team: San Diego St. (Rank: 56)
# Scores: 62 - 84
# Winner: San Diego St.
# WAW Score: 39.2
#
# North Ala., Tennessee Tech, 82, 59, 152, 292, North Ala., 37.8, |
#
#
# Home Team: North Ala. (Rank: 152) vs Away Team: Tennessee Tech (Rank: 292)
# Scores: 82 - 59
# Winner: North Ala.
# WAW Score: 37.8
#
# Wofford, Gardner-Webb, 88, 64, 166, 215, Wofford, 36.4, |
#
#
# Home Team: Wofford (Rank: 166) vs Away Team: Gardner-Webb (Rank: 215)
# Scores: 88 - 64
# Winner: Wofford
# WAW Score: 36.4
#
# Wichita St., Alcorn, 78, 54, 124, 350, Wichita St., 36.4, |
#
#
# Home Team: Wichita St. (Rank: 124) vs Away Team: Alcorn (Rank: 350)
# Scores: 78 - 54
# Winner: Wichita St.
# WAW Score: 36.4
#
# Lehigh, Monmouth, 90, 63, 271, 305, Lehigh, 32.2, |
#
#
# Home Team: Lehigh (Rank: 271) vs Away Team: Monmouth (Rank: 305)
# Scores: 90 - 63
# Winner: Lehigh
# WAW Score: 32.2
#
# Colgate, Cornell, 57, 84, 261, 99, Cornell, 32.2, |
#
#
# Home Team: Colgate (Rank: 261) vs Away Team: Cornell (Rank: 99)
# Scores: 57 - 84
# Winner: Cornell
# WAW Score: 32.2
#
# UIC, UNI, 56, 83, 224, 73, UNI, 32.2, |
#
#
# Home Team: UIC (Rank: 224) vs Away Team: UNI (Rank: 73)
# Scores: 56 - 83
# Winner: UNI
# WAW Score: 32.2
#
# Colorado St., LMU (CA), 83, 54, 128, 204, Colorado St., 29.4, |
#
#
# Home Team: Colorado St. (Rank: 128) vs Away Team: LMU (CA) (Rank: 204)
# Scores: 83 - 54
# Winner: Colorado St.
# WAW Score: 29.4
#
# USC Upstate, Brevard, 91, 60, 342, 400, USC Upstate, 26.6, |
#
#
# Home Team: USC Upstate (Rank: 342) vs Away Team: Brevard (Rank: 400)
# Scores: 91 - 60
# Winner: USC Upstate
# WAW Score: 26.6
#
# Western Ill., St. Ambrose, 97, 64, 313, 400, Western Ill., 23.8, |
#
#
# Home Team: Western Ill. (Rank: 313) vs Away Team: St. Ambrose (Rank: 400)
# Scores: 97 - 64
# Winner: Western Ill.
# WAW Score: 23.8
#
# VCU, Ga. Southern, 89, 54, 66, 231, VCU, 21.0, |
#
#
# Home Team: VCU (Rank: 66) vs Away Team: Ga. Southern (Rank: 231)
# Scores: 89 - 54
# Winner: VCU
# WAW Score: 21.0
#
# Middle Tenn., Rhodes, 103, 55, 130, 400, Middle Tenn., 2.8, |
#
#
# Home Team: Middle Tenn. (Rank: 130) vs Away Team: Rhodes (Rank: 400)
# Scores: 103 - 55
# Winner: Middle Tenn.
# WAW Score: 2.8
#
# Texas St., Arlington Baptist, 97, 49, 123, 400, Texas St., 2.8, |
#
#
# Home Team: Texas St. (Rank: 123) vs Away Team: Arlington Baptist (Rank: 400)
# Scores: 97 - 49
# Winner: Texas St.
# WAW Score: 2.8
#
# Morgan St., Cheyney, 124, 57, 354, 400, Morgan St., 0.0, |
#
#
# Home Team: Morgan St. (Rank: 354) vs Away Team: Cheyney (Rank: 400)
# Scores: 124 - 57
# Winner: Morgan St.
# WAW Score: 0.0
#
# Saint Francis, Penn St.-Shenango, 107, 55, 290, 400, Saint Francis, 0.0, |
#
#
# Home Team: Saint Francis (Rank: 290) vs Away Team: Penn St.-Shenango (Rank: 400)
# Scores: 107 - 55
# Winner: Saint Francis
# WAW Score: 0.0
#
# William & Mary, Virginia-Lynchburg, 109, 55, 243, 400, William & Mary, 0.0, |
#
#
# Home Team: William & Mary (Rank: 243) vs Away Team: Virginia-Lynchburg (Rank: 400)
# Scores: 109 - 55
# Winner: William & Mary
# WAW Score: 0.0
#
# LIU, York (NY), 103, 53, 317, 400, LIU, 0.0, |
#
#
# Home Team: LIU (Rank: 317) vs Away Team: York (NY) (Rank: 400)
# Scores: 103 - 53
# Winner: LIU
# WAW Score: 0.0
#
# Lindenwood, East-West U., 102, 45, 303, 400, Lindenwood, 0.0, |
#
#
# Home Team: Lindenwood (Rank: 303) vs Away Team: East-West U. (Rank: 400)
# Scores: 102 - 45
# Winner: Lindenwood
# WAW Score: 0.0
#
# Pepperdine, LIFE Pacific, 119, 57, 220, 400, Pepperdine, 0.0, |
#
#
# Home Team: Pepperdine (Rank: 220) vs Away Team: LIFE Pacific (Rank: 400)
# Scores: 119 - 57
# Winner: Pepperdine
# WAW Score: 0.0
